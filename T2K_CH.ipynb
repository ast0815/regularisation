# %%
import numpy as np
import uproot as up
import utils
from matplotlib import pyplot as plt
from scipy.linalg import cholesky, sqrtm
from scipy.optimize import minimize
from scipy.stats import norm, rv_histogram

# %%
# Results from NUISANCE
F = up.open("0pi/nuisance.root")
unfolded_h = F["T2K_NuMu_CC0pi_CH_XSec_2DPcos_data"].to_numpy()
bins = unfolded_h[1]
unfolded_h = (unfolded_h[0] * 1e38, bins)

# %%
# MC (GENIEv3 G18_10a_02_11a)
MC_h = F["T2K_NuMu_CC0pi_CH_XSec_2DPcos_MC"].to_numpy()
MC_h = (MC_h[0] * 1e38, bins)

# %%
plt.stairs(*unfolded_h, label="data")
plt.stairs(*MC_h, label="MC")
plt.legend()

# %%
# Error bars
cov_unfolded = F["T2K_NuMu_CC0pi_CH_XSec_2DPcos_COV"].to_numpy()[0]
# cov_unfolded = np.diag(MC_h[0] ** 2) * 0.1
# cov_unfolded = np.diag(np.diag(cov_unfolded))
cor_unfolded = cov_unfolded / (
    np.sqrt(np.diag(cov_unfolded))[:, None] * np.sqrt(np.diag(cov_unfolded))[None, :]
)
cov_unfolded_inv = np.linalg.inv(cov_unfolded)
cor_unfolded[~np.isfinite(cor_unfolded)] = 0

(
    np.sqrt(np.max(np.diag(cov_unfolded))),
    np.max(cor_unfolded),
    np.min(cor_unfolded),
    np.min(cov_unfolded),
)
# Out:
# (0.13384559580517774,
#  1.0000000000000002,
#  -0.30541647308027997,
#  -0.0027006233969233216)

# %%
plt.matshow(cor_unfolded, cmap="coolwarm", vmin=-1, vmax=1)
plt.colorbar()

# %%
# Regularisation
C = utils.Q1s(MC_h[0])
plt.matshow(C)
plt.colorbar()

# %%
# Regularised result
#
# m' = A m
# A = (cov^{-1} + C)^-1 cov^{-1}

tau_list = [0.0] + list(np.logspace(0, 2, 9 + 8))
A_list = [
    np.linalg.inv(cov_unfolded_inv + tau * C) @ cov_unfolded_inv for tau in tau_list
]
regularised_list = [A @ unfolded_h[0] for A in A_list]

# %%
plt.matshow(A_list[-1], cmap="coolwarm", vmin=-np.max(A_list[-1]))
plt.colorbar()

# %%
for x, tau in zip(regularised_list, tau_list):
    plt.stairs(x, bins, label=fr"$\tau = {tau:3.1f}$")
plt.legend(ncol=2)

# %%
# Metrics
jaggedness = [x.T @ C @ x for x in regularised_list]
bias = [
    (x - unfolded_h[0]).T @ cov_unfolded_inv @ (x - unfolded_h[0])
    for x in regularised_list
]

# %%
plt.plot(bias, jaggedness)
plt.xlabel("bias")
plt.ylabel("jaggedness")
for x, y, tau in zip(bias, jaggedness, tau_list):
    plt.annotate(fr"$\tau = {tau:.1f}$", (x, y))

# %%
# Alt metrics
# Determinant of covariance/correlation matrix as measure of overall correlation?
cov_list = [A @ cov_unfolded @ A.T for A in A_list]
cor_list = [
    np.diag(np.diag(cov) ** (-0.5)) @ cov @ np.diag(np.diag(cov) ** (-0.5))
    for cov in cov_list
]
cov_det_list = [np.linalg.det(cov) for cov in cov_list]
cor_det_list = [np.linalg.det(cor) for cor in cor_list]

# %%
plt.matshow(cor_list[-1], cmap="coolwarm", vmin=-1, vmax=1)
plt.colorbar()

# %%
# Alt metrics
# Wasserstein distance in uncorrelated standard normal space
# The Fréchet distance between multivariate normal distributions
# https://doi.org/10.1016/0047-259X(82)90077-X
dist = []
diag_dist = []


def wasserstein(x, cov, base_x=unfolded_h[0], base_cov=cov_unfolded):
    U = cholesky(np.linalg.inv(base_cov))
    m = U @ base_x
    diff = m - U @ x
    S = U @ cov @ U.T
    d = diff.T @ diff + cov.shape[0] + np.trace(S - 2 * sqrtm(S))
    return abs(d)  # Catch some numerical issues


for x, cov in zip(regularised_list, cov_list):
    # Distance between original and regularised
    dist.append(wasserstein(x, cov))
    # Distance between original and plot
    diag_dist.append(wasserstein(x, np.diag(np.diag(cov))))

# %%
plt.plot(bias, jaggedness, label="M distance$^2$")
plt.plot(dist, jaggedness, label="W distance$^2$")
plt.legend()
plt.xlabel("bias")
plt.ylabel("jaggedness")
for x, y, tau in zip(dist, jaggedness, tau_list):
    plt.annotate(fr"$\tau = {tau:.1f}$", (x, y))

# %%
plt.plot(dist, diag_dist)
plt.xlabel("regularisation bias $W^2_{reg}$")
plt.ylabel("plot bias $W^2_{plot}$")
i_W = 0
best = np.inf
for i, (x, y, tau) in enumerate(zip(dist, diag_dist, tau_list)):
    plt.annotate(fr"$\tau = {tau:.1f}$", (x, y))
    if y < best:
        best = y
        i_W = i

# %%
plt.plot(dist, cor_det_list)
plt.xlabel("bias")
plt.ylabel(r"$|cor|$")
i_D = 0
best = 0
for i, (x, y, tau) in enumerate(zip(dist, cor_det_list, tau_list)):
    plt.annotate(fr"$\tau = {tau:.1f}$", (x, y))
    if y > best:
        best = y
        i_D = i

# %%
plt.stairs(*unfolded_h, label="unreg", linewidth=2)
plt.stairs(regularised_list[i_W], bins, label="W-reg")
plt.legend()

# %%
x = (bins[:-1] + bins[1:]) / 2
xerr = (bins[1:] - bins[:-1]) / 2

y = unfolded_h[0]
yerr = np.sqrt(np.diag(cov_unfolded))
plt.errorbar(
    x, y, yerr=yerr, xerr=xerr, label="unreg", linewidth=2, linestyle="", capsize=4
)

y = regularised_list[i_W]
yerr = np.sqrt(np.diag(cov_list[i_W]))
plt.errorbar(
    x, y, yerr=yerr, xerr=xerr, label="W-reg", linewidth=2, linestyle="", capsize=4
)

plt.stairs(*MC_h, label="MC")

plt.legend()

# %%
# Fit scaling
def minfun(p, base=None, grad=None):
    if base is None:
        base = MC_h[0]
    if grad is None:
        grad = np.ones_like(base)
    mc = base * (1.0 + p * grad)
    diff = unfolded_h[0] - mc
    return diff.T @ cov_unfolded_inv @ diff


ret = minimize(minfun, x0=0.0)
print(ret)
MC_fit = MC_h[0] * (1.0 + ret.x[0])

# MC_nofit = MC_fit * np.sum(regularised_list[i_W]) / np.sum(MC_fit)
MC_nofit = MC_fit * np.sum(unfolded_h[0]) / np.sum(MC_fit)
# Out:
#       fun: 109.91554052201039
#  hess_inv: array([[1]])
#       jac: array([3.81469727e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 6
#       nit: 1
#      njev: 3
#    status: 0
#   success: True
#         x: array([-0.24783418])

# %%
x = (bins[:-1] + bins[1:]) / 2
xerr = (bins[1:] - bins[:-1]) / 2

y = regularised_list[i_W]
yerr = np.sqrt(np.diag(cov_list[i_W]))
plt.errorbar(
    x, y, yerr=yerr, xerr=xerr, label="W-reg", linewidth=2, linestyle="", capsize=4
)

A = A_list[i_W]
reg_cov = cov_list[i_W]
reg_cov_inv = np.linalg.inv(reg_cov)

model = MC_h[0]
diff = y - A @ model
chi = diff.T @ reg_cov_inv @ diff
grad = utils.xsec_grad(model, y, reg_cov_inv, A)

plt.stairs(model, bins, label=f"MC: {chi:.1f} / {len(grad)}")
for ax, ay, dy in zip(x, MC_h[0], grad):
    plt.arrow(
        ax,
        ay,
        0,
        dy,
        head_width=0.5,
        length_includes_head=True,
        head_length=np.abs(dy),
        color="C1",
    )

model = MC_fit
diff = y - A @ model
chi = diff.T @ reg_cov_inv @ diff
grad = utils.xsec_grad(model, y, reg_cov_inv, A)

plt.stairs(model, bins, label=f"MC fit: {chi:.1f} / {len(grad)}")
for ax, ay, dy in zip(x, MC_fit, grad):
    plt.arrow(
        ax,
        ay,
        0,
        dy,
        head_width=0.5,
        length_includes_head=True,
        head_length=np.abs(dy),
        color="C2",
    )

model = MC_nofit
diff = y - A @ model
chi = diff.T @ reg_cov_inv @ diff
grad = utils.xsec_grad(model, y, reg_cov_inv, A)

plt.stairs(model, bins, label=f"MC nofit: {chi:.1f} / {len(grad)}")
for ax, ay, dy in zip(x, MC_fit, grad):
    plt.arrow(
        ax,
        ay,
        0,
        dy,
        head_width=0.5,
        length_includes_head=True,
        head_length=np.abs(dy),
        color="C2",
    )

# plt.yscale("log")
plt.legend()

# %%
# data / MC
norm = MC_h[0]
ys = regularised_list[i_W] / norm
yerrs = np.sqrt(np.diag(cov_list[i_W])) / norm
plt.errorbar(
    x,
    ys,
    yerr=yerrs,
    xerr=xerr,
    label="regularised data",
    linewidth=2,
    linestyle="",
    capsize=4,
    alpha=0.5,
)

model = MC_h[0]
chi = utils.chi2(model, unfolded_h[0], cov_unfolded_inv)
grad = utils.scaled_grad(norm, model, unfolded_h[0], cov_unfolded_inv)
chi_grad = utils.chi2(model * (grad + 1.0), unfolded_h[0], cov_unfolded_inv)
print(np.sum(grad), chi_grad)
ys = model / norm
# plt.stairs(ys, bins, baseline=None, color="C1")
plt.axhline(1.0, color="C1", label=f"MC: {chi:.1f} / {len(model)}")
for ax, ay, dy in zip(x, ys, grad):
    ar = plt.arrow(
        ax,
        ay,
        0,
        dy,
        head_width=0.5,
        length_includes_head=True,
        head_length=np.abs(dy),
        color="C1",
    )
ar.set_label(f"local gradient: {chi_grad:.1f} / {len(model)}")

plt.legend()
plt.ylabel("XSEC / MC")
plt.xlabel("bin number")
# Out:
# -0.5494410755599175 38.259703224200294
# Text(0.5, 0, 'bin number')

# %%
# data / MC
norm = MC_fit
ys = regularised_list[i_W] / norm
yerrs = np.sqrt(np.diag(cov_list[i_W])) / norm
plt.errorbar(
    x,
    ys,
    yerr=yerrs,
    xerr=xerr,
    label="regularised data",
    linewidth=2,
    linestyle="",
    capsize=4,
    alpha=0.5,
)

model = MC_fit
chi = utils.chi2(model, unfolded_h[0], cov_unfolded_inv)
grad = utils.scaled_grad(norm, model, unfolded_h[0], cov_unfolded_inv)
chi_grad = utils.chi2(model * (grad + 1.0), unfolded_h[0], cov_unfolded_inv)
print(np.sum(grad), chi_grad)
ys = model / norm
# plt.stairs(ys, bins, baseline=None, color="C1")
plt.axhline(1.0, color="C2", label=f"MC fit: {chi:.1f} / {len(model)}")
for ax, ay, dy in zip(x, ys, grad):
    ar = plt.arrow(
        ax,
        ay,
        0,
        dy,
        head_width=0.5,
        length_includes_head=True,
        head_length=np.abs(dy),
        color="C2",
    )
ar.set_label(f"local gradient: {chi_grad:.1f} / {len(model)}")

plt.legend()
plt.ylabel("XSEC / MC")
plt.xlabel("bin number")
# Out:
# 4.3105218283656654e-09 57.29773974132412
# Text(0.5, 0, 'bin number')

# %%
# data / MC
norm = MC_nofit
ys = regularised_list[i_W] / norm
yerrs = np.sqrt(np.diag(cov_list[i_W])) / norm
plt.errorbar(
    x,
    ys,
    yerr=yerrs,
    xerr=xerr,
    label="regularised data",
    linewidth=2,
    linestyle="",
    capsize=4,
    alpha=0.5,
)

model = MC_nofit
chi = utils.chi2(model, unfolded_h[0], cov_unfolded_inv)
grad = utils.scaled_grad(norm, model, unfolded_h[0], cov_unfolded_inv)
chi_grad = utils.chi2(model * (grad + 1.0), unfolded_h[0], cov_unfolded_inv)
print(np.sum(grad), chi_grad)
ys = model / norm
# plt.stairs(ys, bins, baseline=None, color="C1")
plt.axhline(1.0, color="C3", label=f"MC scaled: {chi:.1f} / {len(model)}")
for ax, ay, dy in zip(x, ys, grad):
    ar = plt.arrow(
        ax,
        ay,
        0,
        dy,
        head_width=0.5,
        length_includes_head=True,
        head_length=np.abs(dy),
        color="C3",
    )
ar.set_label(f"local gradient: {chi_grad:.1f} / {len(model)}")

plt.legend()
plt.ylabel("XSEC / MC")
plt.xlabel("bin number")
# Out:
# -0.8183588639769298 42.83448637856292
# Text(0.5, 0, 'bin number')

# %%
# log(XSEC / DATA)
norm = unfolded_h[0]
# norm = regularised_list[i_W]
# norm = MC_h[0]
# norm = np.ones_like(MC_h[0])
ys = regularised_list[i_W] / norm
yerrs = np.sqrt(np.diag(cov_list[i_W])) / norm
plt.errorbar(
    x,
    ys,
    yerr=yerrs,
    xerr=xerr,
    label="W-reg",
    linewidth=2,
    linestyle="",
    capsize=4,
    alpha=0.5,
)

model = MC_h[0]
grad = utils.log_grad(model, unfolded_h[0], cov_unfolded_inv)
print(np.sum(grad))
ys = model / norm
plt.stairs(ys, bins, color="C1")
for ax, ay, dy in zip(x, ys, grad):
    dy = ay * (np.exp(dy) - 1)
    plt.arrow(
        ax,
        ay,
        0,
        dy,
        head_width=0.5,
        length_includes_head=True,
        head_length=np.abs(dy),
        color="C1",
    )

model = MC_fit
grad = utils.log_grad(model, unfolded_h[0], cov_unfolded_inv)
print(np.sum(grad))
ys = model / norm
plt.stairs(ys, bins, color="C2")
for ax, ay, dy in zip(x, model / norm, grad):
    plt.arrow(
        ax,
        ay,
        0,
        ay * (np.exp(dy) - 1),
        head_width=0.5,
        length_includes_head=True,
        head_length=np.abs(ay * (np.exp(dy) - 1)),
        color="C2",
    )

for scale in ():
    model = MC_h[0] * scale
    grad = utils.log_grad(model, unfolded_h[0], cov_unfolded_inv)
    print(np.sum(grad))
    ys = model / norm
    plt.stairs(ys, bins, color="C3")
    for ax, ay, dy in zip(x, model / norm, grad):
        plt.arrow(
            ax,
            ay,
            0,
            ay * (np.exp(dy) - 1),
            head_width=0.5,
            length_includes_head=True,
            head_length=np.abs(ay * (np.exp(dy) - 1)),
            color="C3",
        )

plt.yscale("log")
plt.ylabel("XSEC / MLE")
plt.axhline(1.0, color="k", linestyle="dashed")
# plt.xlim(0,20)
# Out:
# -0.5590260621124535
# 4.391778607448771e-09
